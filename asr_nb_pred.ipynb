# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ASR/speech_separation-master/data/audio/
# !ls
# Out:
# /content/drive/MyDrive/ASR/speech_separation-master/data/audio
# audio_downloader.py  AV_model_database		 catalog
# audio_norm.py	     build_audio_database.py	 norm_audio_train
# audio_train	     build_audio_database_v2.py

# %%
# !pip install youtube-dl
# !apt-get install libsox-fmt-all libsox-dev sox > /dev/null
# Out:
# ...
#      |████████████████████████████████| 1.9MB 27.8MB/s
# ...

# %%
# !python3 audio_downloader.py
# Out:
# Streaming output truncated to the last 5000 lines.
# video:0kB audio:33177kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000230%
# [youtube] FCXcTSlIfZk: Downloading webpage
# WARNING: Unable to download webpage: HTTP Error 429: Too Many Requests
# [youtube] FCXcTSlIfZk: Downloading API JSON
# [youtube] FCXcTSlIfZk: Downloading API JSON
# [download] Destination: oaudio_train868.wav
# [download] 100% of 8.85MiB in 00:01
# [ffmpeg] Post-process file oaudio_train868.wav exists, skipping
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !python3 audio_norm.py

# %%
# %cd ../video
# Out:
# /content/drive/MyDrive/ASR/speech_separation-master/data/video

# %%
# !ls
# Out:
# frame_inspector.py  frames  MTCNN_detect.py  video_download.py	video_train

# %%
# !python3 video_download.py
# Out:
# Streaming output truncated to the last 5000 lines.
# [libx264 @ 0x556583652000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x556583652000] ref P L0: 67.6% 13.0% 14.7%  4.8%
# [libx264 @ 0x556583652000] ref B L0: 92.1%  6.4%  1.4%
# [libx264 @ 0x556583652000] ref B L1: 96.4%  3.6%
# [libx264 @ 0x556583652000] kb/s:798.41
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 32.0MB/s
# ...

# %%
# !python3 MTCNN_detect.py
# Out:
# Streaming output truncated to the last 5000 lines.
# face is not related to given coord: 276-71.jpg
# change person from
# [490, 112, 187, 250]
# to
# face is not related to given coord: 276-72.jpg
# change person from
# [489, 114, 188, 251]
# to
# face is not related to given coord: 276-73.jpg
# change person from
# [491, 119, 183, 241]
# to
# face is not related to given coord: 276-74.jpg
# change person from
# [497, 123, 181, 231]
# to
# face is not related to given coord: 276-75.jpg
# 277-01.jpg   [234, 96, 86, 112]
# 277-01.jpg   270.00064000000003 148.00032
# 277-02.jpg   [233, 95, 88, 114]
# 277-02.jpg   270.00064000000003 148.00032
# 277-03.jpg   [233, 95, 88, 114]
# 277-03.jpg   270.00064000000003 148.00032
# 277-04.jpg   [235, 95, 89, 113]
# 277-04.jpg   270.00064000000003 148.00032
# 277-05.jpg   [235, 95, 88, 113]
# 277-05.jpg   270.00064000000003 148.00032
# 277-06.jpg   [234, 94, 89, 114]
# 277-06.jpg   270.00064000000003 148.00032
# 277-07.jpg   [231, 92, 92, 117]
# ...

# %%
# !python3 frame_inspector.py
# Out:
# processing frame 0
# frame 0 is not valid
# processing frame 1
# frame 1 is not valid
# processing frame 2
# processing frame 3
# processing frame 4
# processing frame 5
# processing frame 6
# processing frame 7
# processing frame 8
# processing frame 9
# processing frame 10
# processing frame 11
# frame 11 is not valid
# processing frame 12
# frame 12 is not valid
# processing frame 13
# processing frame 14
# processing frame 15
# processing frame 16
# frame 16 is not valid
# processing frame 17
# processing frame 18
# processing frame 19
# processing frame 20
# processing frame 21
# frame 21 is not valid
# processing frame 22
# frame 22 is not valid
# processing frame 23
# processing frame 24
# frame 24 is not valid
# processing frame 25
# processing frame 26
# frame 26 is not valid
# processing frame 27
# frame 27 is not valid
# processing frame 28
# frame 28 is not valid
# processing frame 29
# processing frame 30
# frame 30 is not valid
# processing frame 31
# ...

# %%
# !ls
# %cd ../audio
# Out:
# face_input	    frames	     valid_frame.txt	video_train
# frame_inspector.py  MTCNN_detect.py  video_download.py
# /content/drive/My Drive/ASR/speech_separation-master/data/audio

# %%
# !ls
# Out:
# audio_downloader.py  build_audio_database.py	 norm_audio_train
# audio_norm.py	     build_audio_database_v2.py
# audio_train	     catalog

# %%
# !python3 build_audio_database_v2.py
# Out:
# 2021-05-11 12:30:37.529378: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# checking...298
# length of the path list:  163
# generate_path_list running time:  0.7754843235015869 ms
# single npy generating... 182
# mixing data...
# number of mix data;  6561
# num of completed mixing audio : 6561

# %%
# %cd ../AV_log/
# Out:
# /content/drive/My Drive/ASR/speech_separation-master/data/AV_log

# %%
# !python3 gentxtnew.py

# %%
# %cd ../../
# !ls
# Out:
# /content/drive/MyDrive/ASR/speech_separation-master
# data  img  LICENSE  model  README.md

# %%
# %cd model/pretrain_model/
# Out:
# /content/drive/MyDrive/ASR/speech_separation-master/model/pretrain_model

# %%
# !python3 pretrain_load_test.py
# Out:
# 2021-05-11 13:02:39.077385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-05-11 13:02:49.500089: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-11 13:02:49.501366: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-11 13:02:49.575735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-11 13:02:49.576599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# %cd model
# !ls
# Out:
# /content/drive/My Drive/ASR/speech_separation-master/model
# lib  model_v1  model_v2  pretrain_model  simple_model

# %%
# %cd model_v2/
# Out:
# /content/drive/My Drive/ASR/speech_separation-master/model/model_v2

# %%
# %cd /content/drive/MyDrive/ASR/speech_separation-master/model/model_v2
# Out:
# /content/drive/.shortcut-targets-by-id/1h-SAaEExPJkQGnDyocs8HH_bRM6qNTHw/ASR/speech_separation-master/model/model_v2

# %%
# !pip uninstall keras 
# !pip install keras==2.2.4
# Out:
# Uninstalling Keras-2.2.4:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/Keras-2.2.4.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/docs/*
#     /usr/local/lib/python3.7/dist-packages/keras/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/docs/md_autogen.py
#     /usr/local/lib/python3.7/dist-packages/docs/update_docs.py
# Proceed (y/n)? y
#   Successfully uninstalled Keras-2.2.4
# ...
#   Using cached https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python3 AV_train.py
# Out:
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "AV_train.py", line 3, in <module>
#   File "../lib/model_AV_new.py", line 1, in <module>
#     from keras import optimizers
#   File "/tensorflow-1.15.2/python3.7/keras/__init__.py", line 3, in <module>
#     from . import utils
#   File "/tensorflow-1.15.2/python3.7/keras/utils/__init__.py", line 6, in <module>
#     from . import conv_utils
#   File "/tensorflow-1.15.2/python3.7/keras/utils/conv_utils.py", line 9, in <module>
#     from .. import backend as K
#   File "/tensorflow-1.15.2/python3.7/keras/backend/__init__.py", line 1, in <module>
#     from .load_backend import epsilon
#   File "/tensorflow-1.15.2/python3.7/keras/backend/load_backend.py", line 90, in <module>
#     from .tensorflow_backend import *
#   File "/tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py", line 5, in <module>
#     import tensorflow as tf
# ...

# %%
# !python3 AV_model_eval.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2021-05-12 14:53:00.563242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-12 14:53:00.595444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-12 14:53:00.596438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
# !pip3 install museval
